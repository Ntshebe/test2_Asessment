# %%
import pandas as pd

df = pd.read_csv("C:/Users/Admin/Downloads/bky6-3za5.csv")

size= df.size
dataType = df.dtypes
columns = df.columns
rows = df.head(9)
slicing = df.iloc[0:5]

missing = df.isnull().sum()

print('Data set size',size)
print('Columns ', columns)
print('Print 9 rows of set ', rows)
print('print first 5 raws ', slicing)
# Out:
# Data set size 9548
# Columns  Index(['is_cluster', 'pocket_name', 'pocket_alias', 'ward_id',
#        'ward_councillor', 'avg_hhsize', 'area_ha', 'density_dwellings',
#        'structure_count', 'age_of_is', 'upgrade_category', 'temp_sanitation',
#        'toilets_full_flush', 'toilets_chemical', 'toilets_portable',
#        'toilets_container', 'toilets_other', 'toilets_total',
#        'ratio_toilets_dwellings', 'pocket_code', 'centroidx', 'centroidy'],
#       dtype='object')
# Print 9 rows of set           is_cluster       pocket_name                pocket_alias   ward_id  \
# 0            4 in 1            4 in 1  Wallacedene 14 / J Section  19100006
# 1       Acacia Road       Acacia Road      Acacia Park - Parktown  19100066
# 2         Amy Biehl         Amy Biehl                 School Site  19100034
# 3       Appel Boord       Appel Boord                         NaN  19100022
# 4            Area K            Area K                 Never Never  19100088
# ...

# %%
df['structure_count_normalized'] = (df['structure_count'] - df['structure_count'].mean()) / df['structure_count'].std()
df['density_dwellings_normalized'] = (df['density_dwellings'] - df['density_dwellings'].mean()) / df['density_dwellings'].std()
